# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model(task.train_data, task.train_labels)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    3.2s finished

# %%
y_pred = model.predict_proba(task.test_data)

f"The ROC AUC score on the test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the test data is 0.8868040711646413'

# %%
task.test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 5595            Private       Craft-repair  Married-civ-spouse       HS-grad
# 29818           Private      Other-service            Divorced       HS-grad
# 480             Private       Craft-repair  Married-civ-spouse    Assoc-acdm
# 28532           Private  Machine-op-inspct  Married-civ-spouse          11th
# 32419           Private    Exec-managerial  Married-civ-spouse     Bachelors
# ...                 ...                ...                 ...           ...
# 7854   Self-emp-not-inc    Farming-fishing       Never-married  Some-college
# 7946            Private  Machine-op-inspct            Divorced  Some-college
# 12168       Federal-gov  Handlers-cleaners            Divorced  Some-college
# 30644           Private      Other-service       Never-married    Assoc-acdm
# 28214  Self-emp-not-inc              Sales  Married-civ-spouse       HS-grad
#
#        hours_per_week  age
# 5595               45   60
# 29818              40   24
# 480                45   33
# 28532              40   52
# 32419              55   36
# ...               ...  ...
# 7854               50   25
# 7946               40   29
# 12168              40   38
# 30644              30   37
# 28214              50   37
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.871314973781681'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.61793611793612

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 5595            Private       Craft-repair  Married-civ-spouse       HS-grad
# 29818           Private      Other-service            Divorced       HS-grad
# 480             Private       Craft-repair  Married-civ-spouse    Assoc-acdm
# 28532           Private  Machine-op-inspct  Married-civ-spouse          11th
# 32419           Private    Exec-managerial  Married-civ-spouse     Bachelors
# ...                 ...                ...                 ...           ...
# 7854   Self-emp-not-inc    Farming-fishing       Never-married  Some-college
# 7946            Private  Machine-op-inspct            Divorced  Some-college
# 12168       Federal-gov  Handlers-cleaners            Divorced  Some-college
# 30644           Private      Other-service       Never-married    Assoc-acdm
# 28214  Self-emp-not-inc              Sales  Married-civ-spouse       HS-grad
#
#        hours_per_week        age
# 5595               45  38.617936
# 29818              40  38.617936
# 480                45  38.617936
# 28532              40  52.000000
# 32419              55  36.000000
# ...               ...        ...
# 7854               50  38.617936
# 7946               40  38.617936
# 12168              40  38.617936
# 30644              30  38.617936
# 28214              50  38.617936
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8818042547827303'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8334395757145934'

# %%
corrupted_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 5595            Private       Craft-repair                 NaN       HS-grad
# 29818           Private      Other-service            Divorced       HS-grad
# 480             Private       Craft-repair                 NaN    Assoc-acdm
# 28532           Private  Machine-op-inspct                 NaN          11th
# 32419           Private    Exec-managerial  Married-civ-spouse     Bachelors
# ...                 ...                ...                 ...           ...
# 7854   Self-emp-not-inc    Farming-fishing                 NaN  Some-college
# 7946            Private  Machine-op-inspct            Divorced  Some-college
# 12168       Federal-gov  Handlers-cleaners                 NaN  Some-college
# 30644           Private      Other-service                 NaN    Assoc-acdm
# 28214  Self-emp-not-inc              Sales                 NaN       HS-grad
#
#        hours_per_week  age
# 5595               45   60
# 29818              40   24
# 480                45   33
# 28532              40   52
# 32419              55   36
# ...               ...  ...
# 7854               50   25
# 7946               40   29
# 12168              40   38
# 30644              30   37
# 28214              50   37
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       12038
# Never-married             8497
# Divorced                  3542
# Widowed                    807
# Separated                  806
# Married-spouse-absent      338
# Married-AF-spouse           20
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 5595            Private       Craft-repair  Married-civ-spouse       HS-grad
# 29818           Private      Other-service            Divorced       HS-grad
# 480             Private       Craft-repair  Married-civ-spouse    Assoc-acdm
# 28532           Private  Machine-op-inspct  Married-civ-spouse          11th
# 32419           Private    Exec-managerial  Married-civ-spouse     Bachelors
# ...                 ...                ...                 ...           ...
# 7854   Self-emp-not-inc    Farming-fishing  Married-civ-spouse  Some-college
# 7946            Private  Machine-op-inspct            Divorced  Some-college
# 12168       Federal-gov  Handlers-cleaners  Married-civ-spouse  Some-college
# 30644           Private      Other-service  Married-civ-spouse    Assoc-acdm
# 28214  Self-emp-not-inc              Sales  Married-civ-spouse       HS-grad
#
#        hours_per_week  age
# 5595               45   60
# 29818              40   24
# 480                45   33
# 28532              40   52
# 32419              55   36
# ...               ...  ...
# 7854               50   25
# 7946               40   29
# 12168              40   38
# 30644              30   37
# 28214              50   37
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8276910272741881'

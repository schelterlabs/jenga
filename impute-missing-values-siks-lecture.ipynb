# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model(task.train_data, task.train_labels)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    2.8s finished

# %%
y_pred = model.predict_proba(task.test_data)

f"The ROC AUC score on the test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the test data is 0.8816049110483648'

# %%
task.test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 14160           Private       Adm-clerical            Divorced  Some-college
# 27048         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 28868           Private    Exec-managerial  Married-civ-spouse     Bachelors
# 5667            Private  Machine-op-inspct       Never-married     Bachelors
# 7827   Self-emp-not-inc       Craft-repair            Divorced  Some-college
# ...                 ...                ...                 ...           ...
# 1338            Private       Tech-support            Divorced     Bachelors
# 24534         Local-gov     Prof-specialty  Married-civ-spouse  Some-college
# 18080           Private     Prof-specialty  Married-civ-spouse   Prof-school
# 10354           Private       Adm-clerical       Never-married     Bachelors
# 24639           Private      Other-service       Never-married       HS-grad
#
#        hours_per_week  age
# 14160              38   27
# 27048              40   45
# 28868              55   29
# 5667               40   30
# 7827               50   29
# ...               ...  ...
# 1338               16   71
# 24534              40   55
# 18080              48   47
# 10354              40   27
# 24639              25   18
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8667148083909569'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.57651259213759

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 14160           Private       Adm-clerical            Divorced  Some-college
# 27048         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 28868           Private    Exec-managerial  Married-civ-spouse     Bachelors
# 5667            Private  Machine-op-inspct       Never-married     Bachelors
# 7827   Self-emp-not-inc       Craft-repair            Divorced  Some-college
# ...                 ...                ...                 ...           ...
# 1338            Private       Tech-support            Divorced     Bachelors
# 24534         Local-gov     Prof-specialty  Married-civ-spouse  Some-college
# 18080           Private     Prof-specialty  Married-civ-spouse   Prof-school
# 10354           Private       Adm-clerical       Never-married     Bachelors
# 24639           Private      Other-service       Never-married       HS-grad
#
#        hours_per_week        age
# 14160              38  27.000000
# 27048              40  38.576513
# 28868              55  38.576513
# 5667               40  38.576513
# 7827               50  38.576513
# ...               ...        ...
# 1338               16  71.000000
# 24534              40  55.000000
# 18080              48  38.576513
# 10354              40  38.576513
# 24639              25  38.576513
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8778996769914844'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8229758643936114'

# %%
corrupted_test_data
# Out:
#               workclass         occupation marital_status     education  \
# 14160           Private       Adm-clerical            NaN  Some-college
# 27048         State-gov    Exec-managerial            NaN       HS-grad
# 28868           Private    Exec-managerial            NaN     Bachelors
# 5667            Private  Machine-op-inspct            NaN     Bachelors
# 7827   Self-emp-not-inc       Craft-repair            NaN  Some-college
# ...                 ...                ...            ...           ...
# 1338            Private       Tech-support            NaN     Bachelors
# 24534         Local-gov     Prof-specialty            NaN  Some-college
# 18080           Private     Prof-specialty            NaN   Prof-school
# 10354           Private       Adm-clerical            NaN     Bachelors
# 24639           Private      Other-service            NaN       HS-grad
#
#        hours_per_week  age
# 14160              38   27
# 27048              40   45
# 28868              55   29
# 5667               40   30
# 7827               50   29
# ...               ...  ...
# 1338               16   71
# 24534              40   55
# 18080              48   47
# 10354              40   27
# 24639              25   18
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       12026
# Never-married             8557
# Divorced                  3523
# Separated                  816
# Widowed                    785
# Married-spouse-absent      322
# Married-AF-spouse           19
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 14160           Private       Adm-clerical  Married-civ-spouse  Some-college
# 27048         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 28868           Private    Exec-managerial  Married-civ-spouse     Bachelors
# 5667            Private  Machine-op-inspct  Married-civ-spouse     Bachelors
# 7827   Self-emp-not-inc       Craft-repair  Married-civ-spouse  Some-college
# ...                 ...                ...                 ...           ...
# 1338            Private       Tech-support  Married-civ-spouse     Bachelors
# 24534         Local-gov     Prof-specialty  Married-civ-spouse  Some-college
# 18080           Private     Prof-specialty  Married-civ-spouse   Prof-school
# 10354           Private       Adm-clerical  Married-civ-spouse     Bachelors
# 24639           Private      Other-service  Married-civ-spouse       HS-grad
#
#        hours_per_week  age
# 14160              38   27
# 27048              40   45
# 28868              55   29
# 5667               40   30
# 7827               50   29
# ...               ...  ...
# 1338               16   71
# 24534              40   55
# 18080              48   47
# 10354              40   27
# 24639              25   18
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8150534745376089'

# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model()

# %%
f"The ROC AUC score on the test data is {task.get_baseline_performance()}"
# Out:
# 'The ROC AUC score on the test data is 0.8835845614128887'

# %%
task.test_data
# Out:
#           workclass       occupation      marital_status     education  \
# 20470       Private            Sales            Divorced          11th
# 25039       Private            Sales  Married-civ-spouse       HS-grad
# 10752     Local-gov            Sales  Married-civ-spouse     Bachelors
# 24062       Private   Prof-specialty  Married-civ-spouse  Some-college
# 17646       Private   Prof-specialty  Married-civ-spouse     Bachelors
# ...             ...              ...                 ...           ...
# 5679            NaN              NaN  Married-civ-spouse     Bachelors
# 28363  Self-emp-inc            Sales  Married-civ-spouse  Some-college
# 7694   Self-emp-inc  Exec-managerial  Married-civ-spouse  Some-college
# 283         Private   Prof-specialty            Divorced     Bachelors
# 15481       Private  Exec-managerial  Married-civ-spouse  Some-college
#
#        hours_per_week  age
# 20470              20   19
# 25039              45   33
# 10752              40   45
# 24062              40   24
# 17646              15   41
# ...               ...  ...
# 5679               10   76
# 28363              90   52
# 7694               50   37
# 283                42   60
# 15481              40   41
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8687577049503954'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.56979422604422

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#           workclass       occupation      marital_status     education  \
# 20470       Private            Sales            Divorced          11th
# 25039       Private            Sales  Married-civ-spouse       HS-grad
# 10752     Local-gov            Sales  Married-civ-spouse     Bachelors
# 24062       Private   Prof-specialty  Married-civ-spouse  Some-college
# 17646       Private   Prof-specialty  Married-civ-spouse     Bachelors
# ...             ...              ...                 ...           ...
# 5679            NaN              NaN  Married-civ-spouse     Bachelors
# 28363  Self-emp-inc            Sales  Married-civ-spouse  Some-college
# 7694   Self-emp-inc  Exec-managerial  Married-civ-spouse  Some-college
# 283         Private   Prof-specialty            Divorced     Bachelors
# 15481       Private  Exec-managerial  Married-civ-spouse  Some-college
#
#        hours_per_week        age
# 20470              20  38.569794
# 25039              45  38.569794
# 10752              40  38.569794
# 24062              40  24.000000
# 17646              15  41.000000
# ...               ...        ...
# 5679               10  38.569794
# 28363              90  38.569794
# 7694               50  38.569794
# 283                42  38.569794
# 15481              40  38.569794
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8788907107729987'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8220291407778619'

# %%
corrupted_test_data
# Out:
#           workclass       occupation      marital_status     education  \
# 20470       Private            Sales                 NaN          11th
# 25039       Private            Sales  Married-civ-spouse       HS-grad
# 10752     Local-gov            Sales                 NaN     Bachelors
# 24062       Private   Prof-specialty                 NaN  Some-college
# 17646       Private   Prof-specialty  Married-civ-spouse     Bachelors
# ...             ...              ...                 ...           ...
# 5679            NaN              NaN                 NaN     Bachelors
# 28363  Self-emp-inc            Sales  Married-civ-spouse  Some-college
# 7694   Self-emp-inc  Exec-managerial                 NaN  Some-college
# 283         Private   Prof-specialty                 NaN     Bachelors
# 15481       Private  Exec-managerial                 NaN  Some-college
#
#        hours_per_week  age
# 20470              20   19
# 25039              45   33
# 10752              40   45
# 24062              40   24
# 17646              15   41
# ...               ...  ...
# 5679               10   76
# 28363              90   52
# 7694               50   37
# 283                42   60
# 15481              40   41
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       11996
# Never-married             8536
# Divorced                  3541
# Separated                  815
# Widowed                    790
# Married-spouse-absent      352
# Married-AF-spouse           18
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#           workclass       occupation      marital_status     education  \
# 20470       Private            Sales  Married-civ-spouse          11th
# 25039       Private            Sales  Married-civ-spouse       HS-grad
# 10752     Local-gov            Sales  Married-civ-spouse     Bachelors
# 24062       Private   Prof-specialty  Married-civ-spouse  Some-college
# 17646       Private   Prof-specialty  Married-civ-spouse     Bachelors
# ...             ...              ...                 ...           ...
# 5679            NaN              NaN  Married-civ-spouse     Bachelors
# 28363  Self-emp-inc            Sales  Married-civ-spouse  Some-college
# 7694   Self-emp-inc  Exec-managerial  Married-civ-spouse  Some-college
# 283         Private   Prof-specialty  Married-civ-spouse     Bachelors
# 15481       Private  Exec-managerial  Married-civ-spouse  Some-college
#
#        hours_per_week  age
# 20470              20   19
# 25039              45   33
# 10752              40   45
# 24062              40   24
# 17646              15   41
# ...               ...  ...
# 5679               10   76
# 28363              90   52
# 7694               50   37
# 283                42   60
# 15481              40   41
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8163766375108087'

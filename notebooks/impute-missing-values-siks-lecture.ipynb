# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model(task.train_data, task.train_labels)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   14.2s finished

# %%
y_pred = model.predict_proba(task.test_data)

f"The ROC AUC score on the test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the test data is 0.8808628129208451'

# %%
task.test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 30462           Private       Craft-repair  Married-civ-spouse     Assoc-voc
# 32069         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 30287           Private       Craft-repair  Married-civ-spouse       HS-grad
# 14177           Private  Handlers-cleaners       Never-married          12th
# 24751           Private  Machine-op-inspct       Never-married       HS-grad
# ...                 ...                ...                 ...           ...
# 7505            Private       Adm-clerical       Never-married    Assoc-acdm
# 9846   Self-emp-not-inc   Transport-moving       Never-married  Some-college
# 6301   Self-emp-not-inc       Craft-repair  Married-civ-spouse       HS-grad
# 28860           Private   Transport-moving       Never-married       HS-grad
# 20644           Private      Other-service       Never-married          12th
#
#        hours_per_week  age
# 30462              57   51
# 32069              40   36
# 30287              40   58
# 14177              20   19
# 24751              40   39
# ...               ...  ...
# 7505               40   53
# 9846               30   43
# 6301               40   30
# 28860              45   28
# 20644              40   71
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.870056537714585'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.56476504914005

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 30462           Private       Craft-repair  Married-civ-spouse     Assoc-voc
# 32069         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 30287           Private       Craft-repair  Married-civ-spouse       HS-grad
# 14177           Private  Handlers-cleaners       Never-married          12th
# 24751           Private  Machine-op-inspct       Never-married       HS-grad
# ...                 ...                ...                 ...           ...
# 7505            Private       Adm-clerical       Never-married    Assoc-acdm
# 9846   Self-emp-not-inc   Transport-moving       Never-married  Some-college
# 6301   Self-emp-not-inc       Craft-repair  Married-civ-spouse       HS-grad
# 28860           Private   Transport-moving       Never-married       HS-grad
# 20644           Private      Other-service       Never-married          12th
#
#        hours_per_week        age
# 30462              57  38.564765
# 32069              40  38.564765
# 30287              40  38.564765
# 14177              20  19.000000
# 24751              40  39.000000
# ...               ...        ...
# 7505               40  38.564765
# 9846               30  38.564765
# 6301               40  38.564765
# 28860              45  38.564765
# 20644              40  38.564765
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8776545471725048'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8188891313171542'

# %%
corrupted_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 30462           Private       Craft-repair                 NaN     Assoc-voc
# 32069         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 30287           Private       Craft-repair                 NaN       HS-grad
# 14177           Private  Handlers-cleaners                 NaN          12th
# 24751           Private  Machine-op-inspct       Never-married       HS-grad
# ...                 ...                ...                 ...           ...
# 7505            Private       Adm-clerical                 NaN    Assoc-acdm
# 9846   Self-emp-not-inc   Transport-moving       Never-married  Some-college
# 6301   Self-emp-not-inc       Craft-repair                 NaN       HS-grad
# 28860           Private   Transport-moving                 NaN       HS-grad
# 20644           Private      Other-service                 NaN          12th
#
#        hours_per_week  age
# 30462              57   51
# 32069              40   36
# 30287              40   58
# 14177              20   19
# 24751              40   39
# ...               ...  ...
# 7505               40   53
# 9846               30   43
# 6301               40   30
# 28860              45   28
# 20644              40   71
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       11952
# Never-married             8585
# Divorced                  3544
# Separated                  839
# Widowed                    775
# Married-spouse-absent      335
# Married-AF-spouse           18
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#               workclass         occupation      marital_status     education  \
# 30462           Private       Craft-repair  Married-civ-spouse     Assoc-voc
# 32069         State-gov    Exec-managerial  Married-civ-spouse       HS-grad
# 30287           Private       Craft-repair  Married-civ-spouse       HS-grad
# 14177           Private  Handlers-cleaners  Married-civ-spouse          12th
# 24751           Private  Machine-op-inspct       Never-married       HS-grad
# ...                 ...                ...                 ...           ...
# 7505            Private       Adm-clerical  Married-civ-spouse    Assoc-acdm
# 9846   Self-emp-not-inc   Transport-moving       Never-married  Some-college
# 6301   Self-emp-not-inc       Craft-repair  Married-civ-spouse       HS-grad
# 28860           Private   Transport-moving  Married-civ-spouse       HS-grad
# 20644           Private      Other-service  Married-civ-spouse          12th
#
#        hours_per_week  age
# 30462              57   51
# 32069              40   36
# 30287              40   58
# 14177              20   19
# 24751              40   39
# ...               ...  ...
# 7505               40   53
# 9846               30   43
# 6301               40   30
# 28860              45   28
# 20644              40   71
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.810777852679363'

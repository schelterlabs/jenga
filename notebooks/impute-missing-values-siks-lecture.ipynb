# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model()

# %%
f"The ROC AUC score on the test data is {task.get_baseline_performance()}"
# Out:
# 'The ROC AUC score on the test data is 0.8835656042788887'

# %%
task.test_data
# Out:
#               workclass        occupation      marital_status     education  \
# 23038  Self-emp-not-inc  Transport-moving           Separated       HS-grad
# 30795           Private      Craft-repair  Married-civ-spouse       HS-grad
# 10734           Private      Craft-repair  Married-civ-spouse  Some-college
# 9733            Private      Adm-clerical             Widowed       HS-grad
# 13522       Federal-gov      Tech-support       Never-married  Some-college
# ...                 ...               ...                 ...           ...
# 23795           Private             Sales            Divorced       HS-grad
# 8091            Private   Exec-managerial  Married-civ-spouse       Masters
# 29601               NaN               NaN  Married-civ-spouse       HS-grad
# 26017           Private  Transport-moving       Never-married  Some-college
# 6647        Federal-gov      Adm-clerical       Never-married          12th
#
#        hours_per_week  age
# 23038              70   35
# 30795              45   34
# 10734              45   35
# 9733               24   69
# 13522              24   20
# ...               ...  ...
# 23795              25   31
# 8091               45   59
# 29601              20   65
# 26017              50   25
# 6647               25   21
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8702776815283744'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.601082616707615

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#               workclass        occupation      marital_status     education  \
# 23038  Self-emp-not-inc  Transport-moving           Separated       HS-grad
# 30795           Private      Craft-repair  Married-civ-spouse       HS-grad
# 10734           Private      Craft-repair  Married-civ-spouse  Some-college
# 9733            Private      Adm-clerical             Widowed       HS-grad
# 13522       Federal-gov      Tech-support       Never-married  Some-college
# ...                 ...               ...                 ...           ...
# 23795           Private             Sales            Divorced       HS-grad
# 8091            Private   Exec-managerial  Married-civ-spouse       Masters
# 29601               NaN               NaN  Married-civ-spouse       HS-grad
# 26017           Private  Transport-moving       Never-married  Some-college
# 6647        Federal-gov      Adm-clerical       Never-married          12th
#
#        hours_per_week        age
# 23038              70  38.601083
# 30795              45  38.601083
# 10734              45  38.601083
# 9733               24  69.000000
# 13522              24  20.000000
# ...               ...        ...
# 23795              25  38.601083
# 8091               45  38.601083
# 29601              20  38.601083
# 26017              50  38.601083
# 6647               25  38.601083
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8784751318388343'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8173750037271653'

# %%
corrupted_test_data
# Out:
#               workclass        occupation      marital_status     education  \
# 23038  Self-emp-not-inc  Transport-moving                 NaN       HS-grad
# 30795           Private      Craft-repair  Married-civ-spouse       HS-grad
# 10734           Private      Craft-repair                 NaN  Some-college
# 9733            Private      Adm-clerical                 NaN       HS-grad
# 13522       Federal-gov      Tech-support       Never-married  Some-college
# ...                 ...               ...                 ...           ...
# 23795           Private             Sales                 NaN       HS-grad
# 8091            Private   Exec-managerial  Married-civ-spouse       Masters
# 29601               NaN               NaN                 NaN       HS-grad
# 26017           Private  Transport-moving                 NaN  Some-college
# 6647        Federal-gov      Adm-clerical                 NaN          12th
#
#        hours_per_week  age
# 23038              70   35
# 30795              45   34
# 10734              45   35
# 9733               24   69
# 13522              24   20
# ...               ...  ...
# 23795              25   31
# 8091               45   59
# 29601              20   65
# 26017              50   25
# 6647               25   21
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       11996
# Never-married             8545
# Divorced                  3540
# Separated                  824
# Widowed                    791
# Married-spouse-absent      332
# Married-AF-spouse           20
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#               workclass        occupation      marital_status     education  \
# 23038  Self-emp-not-inc  Transport-moving  Married-civ-spouse       HS-grad
# 30795           Private      Craft-repair  Married-civ-spouse       HS-grad
# 10734           Private      Craft-repair  Married-civ-spouse  Some-college
# 9733            Private      Adm-clerical  Married-civ-spouse       HS-grad
# 13522       Federal-gov      Tech-support       Never-married  Some-college
# ...                 ...               ...                 ...           ...
# 23795           Private             Sales  Married-civ-spouse       HS-grad
# 8091            Private   Exec-managerial  Married-civ-spouse       Masters
# 29601               NaN               NaN  Married-civ-spouse       HS-grad
# 26017           Private  Transport-moving  Married-civ-spouse  Some-college
# 6647        Federal-gov      Adm-clerical  Married-civ-spouse          12th
#
#        hours_per_week  age
# 23038              70   35
# 30795              45   34
# 10734              45   35
# 9733               24   69
# 13522              24   20
# ...               ...  ...
# 23795              25   31
# 8091               45   59
# 29601              20   65
# 26017              50   25
# 6647               25   21
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8173750037271653'

# %%
import numpy as np

# %%
from jenga.tasks.income import IncomeEstimationTask

task = IncomeEstimationTask(seed=42)

# %%
model = task.fit_baseline_model()

# %%
f"The ROC AUC score on the test data is {task.get_baseline_performance()}"
# Out:
# 'The ROC AUC score on the test data is 0.8771970030335221'

# %%
task.test_data
# Out:
#               workclass       occupation      marital_status     education  \
# 16309           Private     Tech-support  Married-civ-spouse       HS-grad
# 29284           Private  Priv-house-serv       Never-married       5th-6th
# 29738  Self-emp-not-inc            Sales       Never-married       HS-grad
# 24747           Private     Tech-support       Never-married       HS-grad
# 30140           Private     Adm-clerical       Never-married  Some-college
# ...                 ...              ...                 ...           ...
# 5020                NaN              NaN       Never-married  Some-college
# 5002            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1156            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1173            Private    Other-service       Never-married     Assoc-voc
# 22613           Private  Exec-managerial       Never-married       Masters
#
#        hours_per_week  age
# 16309              40   38
# 29284              40   27
# 29738              40   31
# 24747              10   18
# 30140              25   21
# ...               ...  ...
# 5020               20   18
# 5002               40   26
# 1156               45   46
# 1173               30   20
# 22613              50   39
#
# [6513 rows x 6 columns]

# %% [markdown]
# ### Missing values in the 'age' column

# %%
from jenga.corruptions.generic import MissingValues

age_corruption = MissingValues(column='age', fraction=0.8, na_value=-1.0)

corrupted_test_data = age_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8529848786552953'

# %% [markdown]
# Cleaning via mean imputation

# %%
mean_age = np.mean(task.train_data.age.values)
mean_age
# Out:
# 38.593596437346434

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data.loc[clean_test_data['age'] < 0, 'age'] = mean_age
clean_test_data
# Out:
#               workclass       occupation      marital_status     education  \
# 16309           Private     Tech-support  Married-civ-spouse       HS-grad
# 29284           Private  Priv-house-serv       Never-married       5th-6th
# 29738  Self-emp-not-inc            Sales       Never-married       HS-grad
# 24747           Private     Tech-support       Never-married       HS-grad
# 30140           Private     Adm-clerical       Never-married  Some-college
# ...                 ...              ...                 ...           ...
# 5020                NaN              NaN       Never-married  Some-college
# 5002            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1156            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1173            Private    Other-service       Never-married     Assoc-voc
# 22613           Private  Exec-managerial       Never-married       Masters
#
#        hours_per_week        age
# 16309              40  38.593596
# 29284              40  38.593596
# 29738              40  38.593596
# 24747              10  18.000000
# 30140              25  21.000000
# ...               ...        ...
# 5020               20  38.593596
# 5002               40  38.593596
# 1156               45  38.593596
# 1173               30  38.593596
# 22613              50  38.593596
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8768871175335453'

# %% [markdown]
# ### Missing values in 'marital_status'

# %%
from jenga.corruptions.generic import MissingValues

marital_status_corruption = MissingValues(column='marital_status', fraction=0.8, na_value=np.nan)

# %%
corrupted_test_data = marital_status_corruption.transform(task.test_data)
y_pred = model.predict_proba(corrupted_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8127799042685139'

# %%
corrupted_test_data
# Out:
#               workclass       occupation      marital_status     education  \
# 16309           Private     Tech-support                 NaN       HS-grad
# 29284           Private  Priv-house-serv       Never-married       5th-6th
# 29738  Self-emp-not-inc            Sales                 NaN       HS-grad
# 24747           Private     Tech-support                 NaN       HS-grad
# 30140           Private     Adm-clerical       Never-married  Some-college
# ...                 ...              ...                 ...           ...
# 5020                NaN              NaN                 NaN  Some-college
# 5002            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1156            Private  Exec-managerial                 NaN       HS-grad
# 1173            Private    Other-service                 NaN     Assoc-voc
# 22613           Private  Exec-managerial                 NaN       Masters
#
#        hours_per_week  age
# 16309              40   38
# 29284              40   27
# 29738              40   31
# 24747              10   18
# 30140              25   21
# ...               ...  ...
# 5020               20   18
# 5002               40   26
# 1156               45   46
# 1173               30   20
# 22613              50   39
#
# [6513 rows x 6 columns]

# %% [markdown]
# Cleaning via mode imputation

# %%
task.train_data['marital_status'].value_counts()
# Out:
# Married-civ-spouse       12003
# Never-married             8525
# Divorced                  3569
# Separated                  814
# Widowed                    786
# Married-spouse-absent      335
# Married-AF-spouse           16
# Name: marital_status, dtype: int64

# %%
clean_test_data = corrupted_test_data.copy(deep=True)
clean_test_data['marital_status'].fillna('Married-civ-spouse', inplace=True)
clean_test_data
# Out:
#               workclass       occupation      marital_status     education  \
# 16309           Private     Tech-support  Married-civ-spouse       HS-grad
# 29284           Private  Priv-house-serv       Never-married       5th-6th
# 29738  Self-emp-not-inc            Sales  Married-civ-spouse       HS-grad
# 24747           Private     Tech-support  Married-civ-spouse       HS-grad
# 30140           Private     Adm-clerical       Never-married  Some-college
# ...                 ...              ...                 ...           ...
# 5020                NaN              NaN  Married-civ-spouse  Some-college
# 5002            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1156            Private  Exec-managerial  Married-civ-spouse       HS-grad
# 1173            Private    Other-service  Married-civ-spouse     Assoc-voc
# 22613           Private  Exec-managerial  Married-civ-spouse       Masters
#
#        hours_per_week  age
# 16309              40   38
# 29284              40   27
# 29738              40   31
# 24747              10   18
# 30140              25   21
# ...               ...  ...
# 5020               20   18
# 5002               40   26
# 1156               45   46
# 1173               30   20
# 22613              50   39
#
# [6513 rows x 6 columns]

# %%
y_pred_cleaned = model.predict_proba(clean_test_data)

f"The ROC AUC score on the corrupted test data is {task.score_on_test_data(y_pred_cleaned)}"
# Out:
# 'The ROC AUC score on the corrupted test data is 0.8127799042685139'

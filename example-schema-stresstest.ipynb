# %%
from jenga.tasks.reviews import VideogameReviewsTask
from jenga.evaluation.schema_stresstest import SchemaStresstest

import tensorflow_data_validation as tfdv

import numpy as np
import pandas as pd

# %% [markdown]
# ### Instantiate the video game reviews task with a randomly chosen seed

# %%
seed = np.random.randint(2**32 - 1)

task = VideogameReviewsTask(seed=seed)

# %% [markdown]
# ### Create a tfdv schema by first auto-infering it from training data and then adjusting it

# %%
train_data_stats = tfdv.generate_statistics_from_dataframe(task.train_data)
schema = tfdv.infer_schema(statistics=train_data_stats)
review_date_feature = tfdv.get_feature(schema, 'review_date')
review_date_feature.distribution_constraints.min_domain_mass = 0.0

# %%
schema
# Out:
# feature {
#   name: "marketplace"
#   type: BYTES
#   domain: "marketplace"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "customer_id"
#   type: BYTES
#   int_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_id"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_id"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_parent"
#   type: BYTES
#   int_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_title"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_category"
#   type: BYTES
#   domain: "product_category"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "star_rating"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "vine"
#   type: BYTES
#   domain: "vine"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "verified_purchase"
#   type: BYTES
#   domain: "verified_purchase"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_headline"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_body"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_date"
#   type: BYTES
#   domain: "review_date"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   distribution_constraints {
#     min_domain_mass: 0.0
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "title_and_review_text"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "marketplace"
#   value: "US"
# }
# string_domain {
#   name: "product_category"
#   value: "Video Games"
# }
# string_domain {
#   name: "vine"
#   value: "N"
#   value: "Y"
# }
# string_domain {
#   name: "verified_purchase"
#   value: "N"
#   value: "Y"
# }
# string_domain {
#   name: "review_date"
#   value: "2015-05-04"
#   value: "2015-05-05"
#   value: "2015-05-06"
#   value: "2015-05-07"
#   value: "2015-05-08"
#   value: "2015-05-09"
#   value: "2015-05-10"
#   value: "2015-05-11"
#   value: "2015-05-12"
#   value: "2015-05-13"
#   value: "2015-05-14"
#   value: "2015-05-15"
#   value: "2015-05-16"
#   value: "2015-05-17"
#   value: "2015-05-18"
#   value: "2015-05-19"
#   value: "2015-05-20"
#   value: "2015-05-21"
#   value: "2015-05-22"
#   value: "2015-05-23"
#   value: "2015-05-24"
#   value: "2015-05-25"
#   value: "2015-05-26"
#   value: "2015-05-27"
#   value: "2015-05-28"
#   value: "2015-05-29"
#   value: "2015-05-30"
#   value: "2015-05-31"
#   value: "2015-06-01"
#   value: "2015-06-02"
#   value: "2015-06-03"
#   value: "2015-06-04"
#   value: "2015-06-05"
#   value: "2015-06-06"
#   value: "2015-06-07"
#   value: "2015-06-08"
#   value: "2015-06-09"
#   value: "2015-06-10"
#   value: "2015-06-11"
#   value: "2015-06-12"
#   value: "2015-06-13"
#   value: "2015-06-14"
# }

# %% [markdown]
# ### Train the baseline model for the task

# %%
model = task.fit_baseline_model(task.train_data, task.train_labels)

# %% [markdown]
# ### Run a stress test for the schema and the model with 250 randomly chosen corruptions, and mark performance drops of 3% as failures

# %%
stress_test = SchemaStresstest()
results = stress_test.run(task, model, schema, num_corruptions=250, performance_threshold=.03)
# Out:
# MissingValues: {'column': 'product_parent', 'fraction': 0.33, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.73}
# MissingValues: {'column': 'review_id', 'fraction': 0.68, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.17}
# MissingValues: {'column': 'product_parent', 'fraction': 0.71, 'sampling': 'MNAR', 'na_value': ''}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.17, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_id', 'fraction': 0.4, 'sampling': 'MAR', 'na_value': ''}
# Scaling: {'column': 'star_rating', 'fraction': 0.54, 'sampling': 'CAR'}
# Scaling: {'column': 'star_rating', 'fraction': 0.52, 'sampling': 'CAR'}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.09, 'sampling': 'CAR'}
# MissingValues: {'column': 'vine', 'fraction': 0.02, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.68}
# MissingValues: {'column': 'review_id', 'fraction': 0.7, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.38, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.61, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.28}
# SwappedValues: {'column': 'title_and_review_text', 'fraction': 0.8, 'sampling': 'CAR', 'swap_with': 'review_body'}
# MissingValues: {'column': 'customer_id', 'fraction': 0.57, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'marketplace', 'fraction': 0.11, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.24}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.06}
# SwappedValues: {'column': 'review_headline', 'fraction': 0.51, 'sampling': 'CAR', 'swap_with': 'product_title'}
# MissingValues: {'column': 'marketplace', 'fraction': 0.34, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_id', 'fraction': 0.73}
# MissingValues: {'column': 'review_body', 'fraction': 0.22, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.83}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.27}
# MissingValues: {'column': 'review_id', 'fraction': 0.27, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.4, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.3, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.84, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'vine', 'fraction': 0.21, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.44}
# MissingValues: {'column': 'review_headline', 'fraction': 0.27, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_title', 'fraction': 0.96, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.66}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.41}
# MissingValues: {'column': 'product_parent', 'fraction': 0.45, 'sampling': 'MAR', 'na_value': ''}
# SwappedValues: {'column': 'review_id', 'fraction': 0.78, 'sampling': 'CAR', 'swap_with': 'customer_id'}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.38}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.16, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.05}
# MissingValues: {'column': 'review_id', 'fraction': 0.84, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.67}
# MissingValues: {'column': 'product_parent', 'fraction': 0.5, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.6, 'sampling': 'MCAR', 'na_value': ''}
# Scaling: {'column': 'star_rating', 'fraction': 0.57, 'sampling': 'CAR'}
# SwappedValues: {'column': 'product_title', 'fraction': 0.02, 'sampling': 'CAR', 'swap_with': 'review_body'}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.77}
# Scaling: {'column': 'star_rating', 'fraction': 0.13, 'sampling': 'CAR'}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.06}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.73}
# MissingValues: {'column': 'product_title', 'fraction': 0.97, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.11}
# SwappedValues: {'column': 'product_parent', 'fraction': 0.85, 'sampling': 'CAR', 'swap_with': 'review_id'}
# MissingValues: {'column': 'customer_id', 'fraction': 0.4, 'sampling': 'MAR', 'na_value': ''}
# SwappedValues: {'column': 'product_parent', 'fraction': 0.92, 'sampling': 'CAR', 'swap_with': 'customer_id'}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.61}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.38, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.39, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.26, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.82}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.05}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.95, 'sampling': 'CAR'}
# MissingValues: {'column': 'marketplace', 'fraction': 0.81, 'sampling': 'MCAR', 'na_value': ''}
# Scaling: {'column': 'star_rating', 'fraction': 0.97, 'sampling': 'CAR'}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.74}
# MissingValues: {'column': 'customer_id', 'fraction': 0.65, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_parent', 'fraction': 0.46, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'verified_purchase', 'fraction': 0.64}
# MissingValues: {'column': 'marketplace', 'fraction': 0.03, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.86, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.29}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.54}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.14}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.63}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.33}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.59}
# MissingValues: {'column': 'marketplace', 'fraction': 0.72, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.23, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.16}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.38}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.64}
# BrokenCharacters: {'column': 'verified_purchase', 'fraction': 0.91}
# MissingValues: {'column': 'review_id', 'fraction': 0.76, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.34}
# MissingValues: {'column': 'review_body', 'fraction': 0.13, 'sampling': 'MCAR', 'na_value': ''}
# SwappedValues: {'column': 'review_id', 'fraction': 0.87, 'sampling': 'CAR', 'swap_with': 'verified_purchase'}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.58}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.71}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.54}
# MissingValues: {'column': 'star_rating', 'fraction': 0.19, 'sampling': 'MCAR', 'na_value': nan}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.16}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.98, 'sampling': 'MAR', 'na_value': ''}
# SwappedValues: {'column': 'product_id', 'fraction': 0.58, 'sampling': 'CAR', 'swap_with': 'vine'}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.09}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.94}
# MissingValues: {'column': 'marketplace', 'fraction': 0.3, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.74, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.03, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.06, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.13, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_body', 'fraction': 0.86, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.46}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.84}
# SwappedValues: {'column': 'title_and_review_text', 'fraction': 0.14, 'sampling': 'CAR', 'swap_with': 'review_body'}
# MissingValues: {'column': 'review_id', 'fraction': 0.03, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.69, 'sampling': 'MCAR', 'na_value': ''}
# SwappedValues: {'column': 'customer_id', 'fraction': 0.19, 'sampling': 'CAR', 'swap_with': 'product_id'}
# MissingValues: {'column': 'product_parent', 'fraction': 0.44, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.74, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.85, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.99, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_id', 'fraction': 0.08}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.61, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_id', 'fraction': 0.99, 'sampling': 'MCAR', 'na_value': ''}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.29, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.55, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.21, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_body', 'fraction': 0.15, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.95, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.3, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_id', 'fraction': 0.52, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_title', 'fraction': 0.27, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.94, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.48, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'verified_purchase', 'fraction': 0.0}
# MissingValues: {'column': 'product_parent', 'fraction': 0.41, 'sampling': 'MAR', 'na_value': ''}
# Scaling: {'column': 'star_rating', 'fraction': 0.22, 'sampling': 'CAR'}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.96}
# SwappedValues: {'column': 'product_title', 'fraction': 0.3, 'sampling': 'CAR', 'swap_with': 'title_and_review_text'}
# MissingValues: {'column': 'vine', 'fraction': 0.72, 'sampling': 'MNAR', 'na_value': ''}
# SwappedValues: {'column': 'product_parent', 'fraction': 0.99, 'sampling': 'CAR', 'swap_with': 'review_id'}
# MissingValues: {'column': 'product_id', 'fraction': 0.98, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.24, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.76, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.63}
# MissingValues: {'column': 'star_rating', 'fraction': 0.28, 'sampling': 'MNAR', 'na_value': nan}
# MissingValues: {'column': 'vine', 'fraction': 0.37, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.57, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_body', 'fraction': 0.29, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'verified_purchase', 'fraction': 0.68}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.77, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.13}
# MissingValues: {'column': 'product_id', 'fraction': 0.03, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_headline', 'fraction': 0.35, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'star_rating', 'fraction': 0.33, 'sampling': 'MNAR', 'na_value': nan}
# MissingValues: {'column': 'review_headline', 'fraction': 0.3, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'star_rating', 'fraction': 0.79, 'sampling': 'MCAR', 'na_value': nan}
# BrokenCharacters: {'column': 'product_id', 'fraction': 0.46}
# MissingValues: {'column': 'product_id', 'fraction': 0.53, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_parent', 'fraction': 0.25, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.12, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.25}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.27}
# MissingValues: {'column': 'marketplace', 'fraction': 0.56, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.08, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.58, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.85, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'title_and_review_text', 'fraction': 0.12, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.76}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.34}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.67}
# MissingValues: {'column': 'vine', 'fraction': 0.12, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_parent', 'fraction': 0.49, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.98}
# SwappedValues: {'column': 'marketplace', 'fraction': 0.59, 'sampling': 'CAR', 'swap_with': 'customer_id'}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.71}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.52, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.72}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.63}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.99}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.88}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.19}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.6}
# Scaling: {'column': 'star_rating', 'fraction': 0.67, 'sampling': 'CAR'}
# Scaling: {'column': 'star_rating', 'fraction': 0.5, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.85, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_title', 'fraction': 0.45, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.59, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'product_title', 'fraction': 0.42, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.25}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.8}
# SwappedValues: {'column': 'review_body', 'fraction': 0.67, 'sampling': 'CAR', 'swap_with': 'review_body'}
# MissingValues: {'column': 'product_title', 'fraction': 0.66, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.62}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.84}
# SwappedValues: {'column': 'verified_purchase', 'fraction': 0.21, 'sampling': 'CAR', 'swap_with': 'product_parent'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.83, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.15}
# MissingValues: {'column': 'product_parent', 'fraction': 0.57, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.37}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.07}
# MissingValues: {'column': 'review_body', 'fraction': 0.53, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_title', 'fraction': 0.74}
# MissingValues: {'column': 'customer_id', 'fraction': 0.24, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.32, 'sampling': 'MCAR', 'na_value': ''}
# GaussianNoise: {'column': 'star_rating', 'fraction': 0.89, 'sampling': 'CAR'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.51, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'star_rating', 'fraction': 0.02, 'sampling': 'MCAR', 'na_value': nan}
# SwappedValues: {'column': 'vine', 'fraction': 0.57, 'sampling': 'CAR', 'swap_with': 'marketplace'}
# BrokenCharacters: {'column': 'verified_purchase', 'fraction': 0.36}
# MissingValues: {'column': 'product_title', 'fraction': 0.82, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'customer_id', 'fraction': 0.29, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.36}
# Scaling: {'column': 'star_rating', 'fraction': 0.49, 'sampling': 'CAR'}
# MissingValues: {'column': 'customer_id', 'fraction': 0.01, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.04, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_id', 'fraction': 0.89}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.61}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.73}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.34}
# MissingValues: {'column': 'customer_id', 'fraction': 0.42, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'marketplace', 'fraction': 0.42, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'product_parent', 'fraction': 0.28, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.55, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.11}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.0}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.69}
# MissingValues: {'column': 'review_headline', 'fraction': 0.77, 'sampling': 'MCAR', 'na_value': ''}
# MissingValues: {'column': 'review_id', 'fraction': 0.32, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.38}
# SwappedValues: {'column': 'marketplace', 'fraction': 0.53, 'sampling': 'CAR', 'swap_with': 'customer_id'}
# MissingValues: {'column': 'review_headline', 'fraction': 0.79, 'sampling': 'MAR', 'na_value': ''}
# SwappedValues: {'column': 'product_title', 'fraction': 0.38, 'sampling': 'CAR', 'swap_with': 'title_and_review_text'}
# MissingValues: {'column': 'product_title', 'fraction': 0.27, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.89}
# MissingValues: {'column': 'product_parent', 'fraction': 0.77, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_id', 'fraction': 0.61}
# MissingValues: {'column': 'review_headline', 'fraction': 0.4, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'vine', 'fraction': 0.57, 'sampling': 'MNAR', 'na_value': ''}
# Scaling: {'column': 'star_rating', 'fraction': 0.82, 'sampling': 'CAR'}
# Scaling: {'column': 'star_rating', 'fraction': 0.9, 'sampling': 'CAR'}
# MissingValues: {'column': 'vine', 'fraction': 0.28, 'sampling': 'MAR', 'na_value': ''}
# MissingValues: {'column': 'vine', 'fraction': 0.48, 'sampling': 'MCAR', 'na_value': ''}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.68}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.12, 'sampling': 'MAR', 'na_value': ''}
# BrokenCharacters: {'column': 'customer_id', 'fraction': 0.46}
# MissingValues: {'column': 'marketplace', 'fraction': 0.71, 'sampling': 'MNAR', 'na_value': ''}
# MissingValues: {'column': 'verified_purchase', 'fraction': 0.84, 'sampling': 'MNAR', 'na_value': ''}
# BrokenCharacters: {'column': 'vine', 'fraction': 0.81}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.76}
# BrokenCharacters: {'column': 'review_id', 'fraction': 0.52}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.03}
# SwappedValues: {'column': 'customer_id', 'fraction': 0.69, 'sampling': 'CAR', 'swap_with': 'marketplace'}
# BrokenCharacters: {'column': 'review_body', 'fraction': 0.46}
# BrokenCharacters: {'column': 'review_headline', 'fraction': 0.56}
# BrokenCharacters: {'column': 'marketplace', 'fraction': 0.52}
# BrokenCharacters: {'column': 'product_parent', 'fraction': 0.21}
# BrokenCharacters: {'column': 'title_and_review_text', 'fraction': 0.92}

# %% [markdown]
# ### Look at the dataframe containing the results

# %%
results
# Out:
#                                             corruption status  \
# 0    MissingValues: {'column': 'product_parent', 'f...     FP
# 1    BrokenCharacters: {'column': 'review_headline'...     TN
# 2    MissingValues: {'column': 'review_id', 'fracti...     TN
# 3    BrokenCharacters: {'column': 'vine', 'fraction...     TN
# 4    MissingValues: {'column': 'product_parent', 'f...     FP
# ..                                                 ...    ...
# 245  BrokenCharacters: {'column': 'review_body', 'f...     TN
# 246  BrokenCharacters: {'column': 'review_headline'...     TN
# 247  BrokenCharacters: {'column': 'marketplace', 'f...     FP
# 248  BrokenCharacters: {'column': 'product_parent',...     TN
# 249  BrokenCharacters: {'column': 'title_and_review...     FN
#
#                                              anomalies  baseline_score  \
# 0    {'product_parent': description: "String values...        0.790875
# 1                                                   {}        0.790875
# 2                                                   {}        0.790875
# 3                                                   {}        0.790875
# 4    {'product_parent': description: "String values...        0.790875
# ..                                                 ...             ...
# 245                                                 {}        0.790875
# 246                                                 {}        0.790875
# 247  {'marketplace': description: "Examples contain...        0.790875
# 248                                                 {}        0.790875
# 249                                                 {}        0.790875
#
#      corrupted_score
# 0           0.790875
# 1           0.790875
# 2           0.790875
# 3           0.790875
# 4           0.790875
# ..               ...
# 245         0.790875
# 246         0.790875
# 247         0.790875
# 248         0.790875
# 249         0.716527
#
# [250 rows x 5 columns]

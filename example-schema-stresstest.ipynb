# %%
from jenga.tasks.reviews import VideogameReviewsTask
from jenga.evaluation.schema_stresstest import SchemaStresstest

import tensorflow_data_validation as tfdv

import numpy as np
import pandas as pd

# %% [markdown]
# ### Instantiate the video game reviews task with a randomly chosen seed

# %%
seed = np.random.randint(2**32 - 1)

task = VideogameReviewsTask(seed=seed)

# %% [markdown]
# ### Create a tfdv schema by first auto-infering it from training data and then adjusting it

# %%
train_data_stats = tfdv.generate_statistics_from_dataframe(task.train_data)
schema = tfdv.infer_schema(statistics=train_data_stats)
review_date_feature = tfdv.get_feature(schema, 'review_date')
review_date_feature.distribution_constraints.min_domain_mass = 0.0

# %%
schema
# Out:
# feature {
#   name: "marketplace"
#   type: BYTES
#   domain: "marketplace"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "customer_id"
#   type: BYTES
#   int_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_id"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_id"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_parent"
#   type: BYTES
#   int_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_title"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product_category"
#   type: BYTES
#   domain: "product_category"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "star_rating"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "vine"
#   type: BYTES
#   domain: "vine"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "verified_purchase"
#   type: BYTES
#   domain: "verified_purchase"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_headline"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_body"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "review_date"
#   type: BYTES
#   domain: "review_date"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   distribution_constraints {
#     min_domain_mass: 0.0
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "title_and_review_text"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "marketplace"
#   value: "US"
# }
# string_domain {
#   name: "product_category"
#   value: "Video Games"
# }
# string_domain {
#   name: "vine"
#   value: "N"
#   value: "Y"
# }
# string_domain {
#   name: "verified_purchase"
#   value: "N"
#   value: "Y"
# }
# string_domain {
#   name: "review_date"
#   value: "2015-05-04"
#   value: "2015-05-05"
#   value: "2015-05-06"
#   value: "2015-05-07"
#   value: "2015-05-08"
#   value: "2015-05-09"
#   value: "2015-05-10"
#   value: "2015-05-11"
#   value: "2015-05-12"
#   value: "2015-05-13"
#   value: "2015-05-14"
#   value: "2015-05-15"
#   value: "2015-05-16"
#   value: "2015-05-17"
#   value: "2015-05-18"
#   value: "2015-05-19"
#   value: "2015-05-20"
#   value: "2015-05-21"
#   value: "2015-05-22"
#   value: "2015-05-23"
#   value: "2015-05-24"
#   value: "2015-05-25"
#   value: "2015-05-26"
#   value: "2015-05-27"
#   value: "2015-05-28"
#   value: "2015-05-29"
#   value: "2015-05-30"
#   value: "2015-05-31"
#   value: "2015-06-01"
#   value: "2015-06-02"
#   value: "2015-06-03"
#   value: "2015-06-04"
#   value: "2015-06-05"
#   value: "2015-06-06"
#   value: "2015-06-07"
#   value: "2015-06-08"
#   value: "2015-06-09"
#   value: "2015-06-10"
#   value: "2015-06-11"
#   value: "2015-06-12"
#   value: "2015-06-13"
#   value: "2015-06-14"
# }

# %% [markdown]
# ### Train the baseline model for the task

# %%
model = task.fit_baseline_model(task.train_data, task.train_labels)

# %% [markdown]
# ### Run a stress test for the schema and the model with 250 randomly chosen corruptions, and mark performance drops of 3% as failures

# %%
stress_test = SchemaStresstest()
results = stress_test.run(task, model, schema, num_corruptions=250, performance_threshold=.03)
# Out:
# MissingValues: {'column': 'star_rating', 'fraction': 0.05, 'sampling': 'MAR', 'na_value': nan}
# SwappedValues: {'column': 'review_id', 'fraction': 'marketplace', 'sampling': 0.14, 'swap_with': None}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9e703f5c660f> in <module>
#       1 stress_test = SchemaStresstest()
# ----> 2 results = stress_test.run(task, model, schema, num_corruptions=250, performance_threshold=.03)
#
# ~/code/jenga/jenga/evaluation/schema_stresstest.py in run(self, task, model, schema, num_corruptions, performance_threshold)
#     111             print(corruption)
#     112             test_data_copy = task.test_data.copy(deep=True)
# --> 113             corrupted_data = corruption.transform(test_data_copy)
#     114
#     115             corrupted_data_stats = tfdv.generate_statistics_from_dataframe(corrupted_data)
#
# ~/code/jenga/jenga/corruptions/generic.py in transform(self, data)
#      78             self.swap_with = np.random.choice([c for c in data.columns if c != self.column])
#      79
# ---> 80         rows = self.sample_rows(df)
#      81
#      82         tmp_vals = df.loc[rows,self.swap_with].copy(deep=True)
#
# ~/code/jenga/jenga/basis.py in sample_rows(self, data)
#      91
#      92         # Completely At Random
# ---> 93         if self.sampling.endswith('CAR'):
#      94             rows = np.random.permutation(data.index)[:int(len(data)*self.fraction)]
#      95         elif self.sampling.endswith('NAR') or self.sampling.endswith('AR'):
#
# AttributeError: 'float' object has no attribute 'endswith'

# %% [markdown]
# ### Look at the dataframe containing the results

# %%
results
